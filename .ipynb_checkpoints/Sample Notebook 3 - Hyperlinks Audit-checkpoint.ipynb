# %%
import pandas as pd
from mrm_template_audit.audit_document_links import audit_document_links

doc_path = './test/sample3.docx'
# --- Execution ---
df_audit = audit_document_links(doc_path)

# Display settings for console
pd.set_option('display.max_colwidth', 50)
display(df_audit)
# Out:
#                 Link Text                 Type  \
# 0        Top of this Page  Internal (Bookmark)
# 1         Sample Document       External (URL)
# 2  Sample Document (docx)       External (URL)
# 3   internal link example  Internal (Bookmark)
#
#                                        Target ID/URL  \
# 0                                               _top
# 1    http://www.dhs.state.il.us/page.aspx?item=67072
# 2  http://www.dhs.state.il.us/OneNetLibrary/27897...
# 3                                     _Simple_Tables
#
#                                          Target Text Audit Status
# 0  [Point at: ContentsSample Document1Headings1Li...      Working
# 1                            [External Web Location]      Unknown
# 2                            [External Web Location]      Unknown
# 3                       [Point at: Simple Tables...]      Working
